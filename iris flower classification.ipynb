# %% [markdown]
# # TASK 3 : IRIS FLOWER CLASSIFICATION

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Loading Dataset

# %%
data=pd.read_csv("/kaggle/input/iris-flower-dataset/IRIS.csv")

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data.shape
# Out:
# (150, 5)

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
data['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
numeric_columns=data.drop(columns='species')
corr=numeric_columns.corr()
fig,axis=plt.subplots(figsize=(10,8))
sns.heatmap(corr,annot=True,ax=axis)
# Out:
# <Axes: >

# %%
le=LabelEncoder()

# %%
data['species']=le.fit_transform(data['species'])
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
X=data.drop(columns='species')
Y=data['species']

# %%
X.shape
# Out:
# (150, 4)

# %%
Y.shape
# Out:
# (150,)

# %% [markdown]
# ## Splitting the Dataset into Training and Testing Sets

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3)

# %% [markdown]
# # Logistic Regression

# %%
model_LogisticRegression = LogisticRegression()

# %%
model_LogisticRegression.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
LogisticRegression_accuracy=model_LogisticRegression.score(x_test,y_test)*100
print(f"Accuracy by using Logistic Regression: {LogisticRegression_accuracy}%")
# Out:
# Accuracy by using Logistic Regression: 95.55555555555556%

# %% [markdown]
# # Decision Tree

# %%
model_DecisionTree=DecisionTreeClassifier()

# %%
model_DecisionTree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
DecisionTree_accuracy=model_DecisionTree.score(x_test,y_test)*100
print(f"Accuracy by using Decision Tree: {DecisionTree_accuracy}%")
# Out:
# Accuracy by using Decision Tree: 93.33333333333333%

# %% [markdown]
# # Random Forest

# %%
model_RandomForest =RandomForestClassifier()

# %%
model_RandomForest.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
RandomForest_accuracy=model_RandomForest.score(x_test,y_test)*100
print(f"Accuracy by using Random Forest: {RandomForest_accuracy}%")
# Out:
# Accuracy by using Random Forest: 91.11111111111111%

# %% [markdown]
# # KNeighbors

# %%
model_KNN = KNeighborsClassifier()

# %%
model_KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
KNN_accuracy=model_KNN.score(x_test,y_test)*100
print(f"Accuracy by using KNN: {KNN_accuracy}%")
# Out:
# Accuracy by using KNN: 93.33333333333333%
